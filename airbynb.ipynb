# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (670 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.0/670.0 kB 8.0 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 10.5 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.7.2

# %%
import pandas as pd
import pymongo

# %%
Client= pymongo.MongoClient("mongodb+srv://bala:balachandran@cluster0.tmbsitp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

db= Client["sample_airbnb"]
coll= db["listingsAndReviews"]

# %%
data= []
for i in coll.find({},{"_id":1, "listing_url":1, "name":1, 'property_type':1, 'room_type':1, 'bed_type':1, 'minimum_nights':1, 'maximum_nights':1, 'cancellation_policy':1, 'accommodates':1, 'bedrooms':1, 'beds':1, 'number_of_reviews':1, 'bathrooms':1, 'price':1, 'extra_people':1, 'guests_included':1, 'images.picture_url':1, 'review_scores':1,'cleaning_fee':1}):
    data.append(i)

# %%
df_1 = pd.DataFrame(data)

# %%
df_1["images"]= df_1["images"].apply(lambda x: x["picture_url"])

# %%
df_1["review_scores"]= df_1["review_scores"].apply(lambda x: x.get("review_scores_rating",0))

# %%
df_1.describe().T
# Out:
#                     count       mean        std  min  25%   50%   75%    max
# accommodates       5555.0   3.505851   2.297019  1.0  2.0   3.0   4.0   16.0
# bedrooms           5550.0   1.411712   1.041942  0.0  1.0   1.0   2.0   20.0
# beds               5542.0   2.071454   1.619660  0.0  1.0   2.0   3.0   25.0
# number_of_reviews  5555.0  27.606481  49.798376  0.0  1.0   5.0  32.0  533.0
# review_scores      5555.0  68.395680  41.829834  0.0  0.0  92.0  98.0  100.0

# %%
# Out:
#         _id                            listing_url  \
# 0  10047964  https://www.airbnb.com/rooms/10047964
#
#                              name property_type        room_type  bed_type  \
# 0  Charming Flat in Downtown Moda         House  Entire home/apt  Real Bed
#
#   minimum_nights maximum_nights cancellation_policy  accommodates  bedrooms  \
# 0              2           1125            flexible             6       2.0
#
#    beds  number_of_reviews bathrooms   price cleaning_fee extra_people  \
# 0   6.0                  1       1.0  527.00       211.00       211.00
#
#   guests_included                                             images  \
# 0               1  https://a0.muscache.com/im/pictures/231120b6-e...
#
#    review_scores
# 0            100

# %%
df_1["bedrooms"].fillna(0,inplace=True)
df_1["beds"].fillna(0,inplace=True)
df_1["bathrooms"].fillna(0,inplace=True)
df_1["cleaning_fee"].fillna(0,inplace=True)

# %%
df_1.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# cleaning_fee           0
# extra_people           0
# guests_included        0
# images                 0
# review_scores          0
# dtype: int64

# %%
df_1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms               object
# price                   object
# cleaning_fee            object
# extra_people            object
# guests_included         object
# images                  object
# review_scores            int64
# dtype: object

# %%
df_1["minimum_nights"]= df_1["minimum_nights"].astype(int)
df_1["maximum_nights"]= df_1["maximum_nights"].astype(int)
df_1["bedrooms"]= df_1["bedrooms"].astype(int)
df_1["beds"]= df_1["beds"].astype(int)
df_1["bathrooms"]= df_1["bathrooms"].astype(str).astype(float).astype(int)
df_1["price"]= df_1["price"].astype(str).astype(float).astype(int)
df_1["extra_people"]= df_1["extra_people"].astype(str).astype(float).astype(int)
df_1["guests_included"]= df_1["guests_included"].astype(str).astype(float).astype(int)
df_1["cleaning_fee"]= df_1["cleaning_fee"].astype(str).astype(float).astype(int)

# %%
df_1.dtypes
# Out:
# _id                    object
# listing_url            object
# name                   object
# property_type          object
# room_type              object
# bed_type               object
# minimum_nights          int64
# maximum_nights          int64
# cancellation_policy    object
# accommodates            int64
# bedrooms                int64
# beds                    int64
# number_of_reviews       int64
# bathrooms               int64
# price                   int64
# cleaning_fee            int64
# extra_people            int64
# guests_included         int64
# images                 object
# review_scores           int64
# dtype: object

# %%
host= []
for i in coll.find({},{"_id":1, "host":1}):
    host.append(i)

# %%
df_host = pd.DataFrame(host)

# %%
df_host
# Out:
#            _id                                               host
# 0     10047964  {'host_id': '1241644', 'host_url': 'https://ww...
# 1      1003530  {'host_id': '454250', 'host_url': 'https://www...
# 2     10083468  {'host_id': '27518920', 'host_url': 'https://w...
# 3     10006546  {'host_id': '51399391', 'host_url': 'https://w...
# 4     10051164  {'host_id': '51326285', 'host_url': 'https://w...
# ...        ...                                                ...
# 5550   9810515  {'host_id': '33325403', 'host_url': 'https://w...
# 5551   9853331  {'host_id': '50141940', 'host_url': 'https://w...
# 5552   9895628  {'host_id': '14856657', 'host_url': 'https://w...
# 5553   9907103  {'host_id': '35533112', 'host_url': 'https://w...
# 5554   9979991  {'host_id': '51283546', 'host_url': 'https://w...
#
# [5555 rows x 2 columns]

# %%
host_columns= {'_id':[],'host_id':[], 'host_url':[], 'host_name':[], 'host_location':[],"host_response_time":[], 'host_thumbnail_url':[], 'host_picture_url':[], 'host_neighbourhood':[], 'host_response_rate':[], 'host_is_superhost':[], 'host_has_profile_pic':[], 'host_identity_verified':[], 'host_listings_count':[], 'host_total_listings_count':[], 'host_verifications':[]}

for i in df_host["_id"]:
    host_columns["_id"].append(i)
for i in df_host["host"]:
    host_columns["host_id"].append(i["host_id"])
    host_columns["host_url"].append(i["host_url"])
    host_columns["host_name"].append(i["host_name"])
    host_columns["host_location"].append(i["host_location"])
    host_columns["host_response_time"].append(i.get("host_response_time"))
    host_columns["host_thumbnail_url"].append(i["host_thumbnail_url"])
    host_columns["host_picture_url"].append(i["host_picture_url"])
    host_columns["host_neighbourhood"].append(i["host_neighbourhood"])
    host_columns["host_response_rate"].append(i.get("host_response_rate"))
    host_columns["host_is_superhost"].append(i["host_is_superhost"])
    host_columns["host_has_profile_pic"].append(i["host_has_profile_pic"])
    host_columns["host_identity_verified"].append(i["host_identity_verified"])
    host_columns["host_listings_count"].append(i["host_listings_count"])
    host_columns["host_total_listings_count"].append(i["host_total_listings_count"])
    host_columns["host_verifications"].append(i["host_verifications"])

# %%
df_host_1 = pd.DataFrame(host_columns)

# %%
df_host_1.isnull().sum()
# Out:
# _id                             0
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_response_time           1388
# host_thumbnail_url              0
# host_picture_url                0
# host_neighbourhood              0
# host_response_rate           1388
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %% [markdown]
# handling null values and empty values

# %%
df_host_1["host_response_time"].fillna("Not Specified",inplace= True)
df_host_1["host_response_rate"].fillna("Not Specified",inplace= True)
df_host_1["host_neighbourhood"]= df_host_1["host_neighbourhood"].replace({'':"Not Specified"})

# %%
df_host_1.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_response_time           0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
# Changing the "True" or "False" features

df_host_1["host_is_superhost"]= df_host_1["host_is_superhost"].map({False: "No", True: "Yes"})
df_host_1["host_has_profile_pic"]= df_host_1["host_has_profile_pic"].map({False: "No", True: "Yes"})
df_host_1["host_identity_verified"]= df_host_1["host_identity_verified"].map({False: "No", True: "Yes"})

# %% [markdown]
# # **collection the address details **

# %%
address= []
for i in coll.find({}, {"_id":1, "address":1}):
    address.append(i)

# %%
df_address = pd.DataFrame(address)

# %%
address_columns= {'_id':[], 'street':[], 'suburb':[], 'government_area':[], 'market':[], 'country':[],
                   'country_code':[], 'location_type':[], "longitude":[], "latitude":[],
                    "is_location_exact":[]}

for i in df_address["_id"]:
    address_columns["_id"].append(i)

for i in df_address["address"]:
    address_columns["street"].append(i["street"])
    address_columns["suburb"].append(i["suburb"])
    address_columns["government_area"].append(i["government_area"])
    address_columns["market"].append(i["market"])
    address_columns["country"].append(i["country"])
    address_columns["country_code"].append(i["country_code"])
    address_columns["location_type"].append(i["location"]["type"])
    address_columns["longitude"].append(i["location"]["coordinates"][0])
    address_columns["latitude"].append(i["location"]["coordinates"][1])
    address_columns["is_location_exact"].append(i["location"]["is_location_exact"])

# %%
df_address_1= pd.DataFrame(address_columns)

# %%
df_address_1.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
# Checking the empty values ('') for all features

#for i in df_address_1.columns:
id_e=[]
stre_e=[]
suburb_e=[]
gov_e=[]
mark_e=[]
cntry_e=[]
cntry_co_e=[]
loc_ty_e=[]
long_e=[]
lat_e=[]
is_loc_tr_e=[]
for index,row in df_address_1.iterrows():
    if row["_id"] == '':
        id_e.append(index)

    if row["street"] == '':
        stre_e.append(index)

    if row["suburb"] == '':
        suburb_e.append(index)

    if row["government_area"] == '':
        gov_e.append(index)

    if row["market"] == '':
        mark_e.append(index)

    if row["country"] == '':
        cntry_e.append(index)

    if row["country_code"] == '':
        cntry_co_e.append(index)

    if row["location_type"] == '':
        loc_ty_e.append(index)

    if row["longitude"] == '':
        long_e.append(index)

    if row["latitude"] == '':
        lat_e.append(index)

    if row["is_location_exact"] == '':
        is_loc_tr_e.append(index)
empty_columns=[id_e,stre_e,suburb_e,gov_e,mark_e,cntry_e,cntry_co_e,loc_ty_e,long_e,lat_e,is_loc_tr_e]
for i in empty_columns:
    print(len(i))
# Out:
# 0
# 0
# 887
# 0
# 6
# 0
# 0
# 0
# 0
# 0
# 0

# %%
# Handling the empty values and Boolian Values
# "suburb" and "market" have a empty values

df_address_1["suburb"]= df_address_1["suburb"].replace({'':"Not Specified"})
df_address_1["market"]= df_address_1["market"].replace({'':"Not Specified"})

df_address_1["is_location_exact"]= df_address_1["is_location_exact"].map({False:"No", True:"Yes"})
df_address_1
# Out:
#            _id                                  street             suburb  \
# 0     10047964               Kadıköy, İstanbul, Turkey               Moda
# 1      1003530             New York, NY, United States          Manhattan
# 2     10083468                  Porto, Porto, Portugal      Not Specified
# 3     10006546                  Porto, Porto, Portugal      Not Specified
# 4     10051164  Rio de Janeiro, Rio de Janeiro, Brazil             Catete
# ...        ...                                     ...                ...
# 5550   9810515           Woolloomooloo, NSW, Australia      Woolloomooloo
# 5551   9853331  Rio de Janeiro, Rio de Janeiro, Brazil             Leblon
# 5552   9895628  Rio de Janeiro, Rio de Janeiro, Brazil    Jardim Botânico
# 5553   9907103                Montréal, Québec, Canada  Downtown Montreal
# 5554   9979991           Hong Kong, Kowloon, Hong Kong           Mong Kok
#
#                                         government_area          market  \
# 0                                               Kadikoy        Istanbul
# 1                                       Upper West Side        New York
# 2     Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 3     Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 4                                                Catete  Rio De Janeiro
# ...                                                 ...             ...
# 5550                                             Sydney          Sydney
# 5551                                             Leblon  Rio De Janeiro
# 5552                                    Jardim Botânico  Rio De Janeiro
# 5553                                        Ville-Marie        Montreal
# 5554                                      Yau Tsim Mong       Hong Kong
#
#             country country_code location_type   longitude   latitude  \
# 0            Turkey           TR         Point   29.031330  40.985850
# 1     United States           US         Point  -73.965230  40.799620
# 2          Portugal           PT         Point   -8.611230  41.152250
# 3          Portugal           PT         Point   -8.613080  41.141300
# 4            Brazil           BR         Point  -43.180157 -22.926382
# ...             ...          ...           ...         ...        ...
# 5550      Australia           AU         Point  151.220670 -33.870070
# 5551         Brazil           BR         Point  -43.219733 -22.982452
# 5552         Brazil           BR         Point  -43.220452 -22.963607
# 5553         Canada           CA         Point  -73.576390  45.496630
# 5554      Hong Kong           HK         Point  114.169630  22.315690
#
#      is_location_exact
# 0                  Yes
# 1                   No
# 2                   No
# 3                   No
# 4                  Yes
# ...                ...
# 5550               Yes
# 5551               Yes
# 5552               Yes
# 5553               Yes
# 5554                No
#
# [5555 rows x 11 columns]

# %%
# avalibility

availability= []
for i in coll.find({}, {"_id":1, "availability":1}):
    availability.append(i)

# %%
df_availabe= pd.DataFrame(availability)

# %%
availabe_columns= {'_id':[], 'availability_30':[], 'availability_60':[], 'availability_90':[], 'availability_365':[]}

for i in df_availabe["_id"]:
    availabe_columns["_id"].append(i)

for i in df_availabe["availability"]:
    availabe_columns["availability_30"].append(i["availability_30"])
    availabe_columns["availability_60"].append(i["availability_60"])
    availabe_columns["availability_90"].append(i["availability_90"])
    availabe_columns["availability_365"].append(i["availability_365"])

# %%
df_availabe_1= pd.DataFrame(availabe_columns)

# %% [markdown]
# # amenities

# %%
amenities= []
for i in coll.find({},{"_id":1, "amenities":1}):
    amenities.append(i)

# %%
df_amenities= pd.DataFrame(amenities)

# %%
def sort_amenities(x):
    a= x
    a.sort()
    return a

# %%
df_amenities["amenities"]= df_amenities["amenities"].apply(lambda x: sort_amenities(x))

# %%
df_amenities
# Out:
#            _id                                          amenities
# 0     10047964  [24-hour check-in, Cable TV, Cat(s), Essential...
# 1      1003530  [Air conditioning, Buzzer/wireless intercom, D...
# 2     10083468  [Accessible-height bed, Bed linens, Cable TV, ...
# 3     10006546  [Bed linens, Buzzer/wireless intercom, Cable T...
# 4     10051164  [Air conditioning, Cable TV, Essentials, Famil...
# ...        ...                                                ...
# 5550   9810515  [24-hour check-in, Air conditioning, Bathtub, ...
# 5551   9853331  [24-hour check-in, Air conditioning, Buzzer/wi...
# 5552   9895628  [Air conditioning, Buzzer/wireless intercom, C...
# 5553   9907103  [24-hour check-in, Air conditioning, Cable TV,...
# 5554   9979991  [Air conditioning, Elevator, Family/kid friend...
#
# [5555 rows x 2 columns]

# %% [markdown]
# Merge all tables

# %%
#df_1
#df_host_1
#df_address_1
#df_availabe_1
#df_amenities
df= pd.merge(df_1, df_host_1, on="_id")
df= pd.merge(df, df_address_1, on="_id")
df= pd.merge(df, df_availabe_1, on="_id")
df= pd.merge(df, df_amenities, on="_id")

# %%
# save the file
df.to_csv("Airbnb.csv", index= False)

# %%
df = pd.read_csv("/content/Airbnb.csv")

# %%
df
# Out:
#            _id                            listing_url  \
# 0     10047964  https://www.airbnb.com/rooms/10047964
# 1      1003530   https://www.airbnb.com/rooms/1003530
# 2     10083468  https://www.airbnb.com/rooms/10083468
# 3     10006546  https://www.airbnb.com/rooms/10006546
# 4     10051164  https://www.airbnb.com/rooms/10051164
# ...        ...                                    ...
# 5550   9810515   https://www.airbnb.com/rooms/9810515
# 5551   9853331   https://www.airbnb.com/rooms/9853331
# 5552   9895628   https://www.airbnb.com/rooms/9895628
# 5553   9907103   https://www.airbnb.com/rooms/9907103
# 5554   9979991   https://www.airbnb.com/rooms/9979991
#
#                                      name property_type        room_type  \
# 0          Charming Flat in Downtown Moda         House  Entire home/apt
# 1     New York City - Upper West Side Apt     Apartment     Private room
# 2                       Be Happy in Porto          Loft  Entire home/apt
# 3                 Ribeira Charming Duplex         House  Entire home/apt
# 4      Catete's Colonial Big Hause Room B         House     Private room
# ...                                   ...           ...              ...
# 5550    Big 2bdm, Views, WIFI and carpark     Apartment  Entire home/apt
# 5551          Amazing apartment in LEBLON     Apartment  Entire home/apt
# 5552  Duplex com vista para o J. Botanico     Apartment  Entire home/apt
# 5553     Brand New Luxury Downtown Studio          Loft  Entire home/apt
# 5554                                  NaN     Apartment  Entire home/apt
#
#       bed_type  minimum_nights  maximum_nights          cancellation_policy  \
# 0     Real Bed               2            1125                     flexible
# 1     Real Bed              12             360  strict_14_with_grace_period
# 2     Real Bed               2            1125                     moderate
# 3     Real Bed               2              30                     moderate
# 4     Real Bed               2            1125  strict_14_with_grace_period
# ...        ...             ...             ...                          ...
# 5550  Real Bed               3            1125  strict_14_with_grace_period
# 5551  Real Bed               1              30  strict_14_with_grace_period
# 5552  Real Bed               5            1125                     flexible
# 5553  Real Bed              90            1125                     moderate
# 5554  Real Bed               1            1125                     flexible
#
#       accommodates  ...  country_code  location_type   longitude   latitude  \
# 0                6  ...            TR          Point   29.031330  40.985850
# 1                2  ...            US          Point  -73.965230  40.799620
# 2                2  ...            PT          Point   -8.611230  41.152250
# 3                8  ...            PT          Point   -8.613080  41.141300
# 4                8  ...            BR          Point  -43.180157 -22.926382
# ...            ...  ...           ...            ...         ...        ...
# 5550             4  ...            AU          Point  151.220670 -33.870070
# 5551             5  ...            BR          Point  -43.219733 -22.982452
# 5552             8  ...            BR          Point  -43.220452 -22.963607
# 5553             2  ...            CA          Point  -73.576390  45.496630
# 5554             3  ...            HK          Point  114.169630  22.315690
#
#       is_location_exact  availability_30  availability_60  availability_90  \
# 0                   Yes               27               57               87
# 1                    No                0                0                0
# 2                    No               16               40               67
# 3                    No               28               47               74
# 4                   Yes               10               10               21
# ...                 ...              ...              ...              ...
# 5550                Yes                8               28               58
# 5551                Yes                7               37               67
# 5552                Yes                0                0                0
# 5553                Yes               29               59               89
# 5554                 No                0                0                0
#
#      availability_365                                          amenities
# 0                 362  ['24-hour check-in', 'Cable TV', 'Cat(s)', 'Es...
# 1                  93  ['Air conditioning', 'Buzzer/wireless intercom...
# 2                 335  ['Accessible-height bed', 'Bed linens', 'Cable...
# 3                 239  ['Bed linens', 'Buzzer/wireless intercom', 'Ca...
# 4                 296  ['Air conditioning', 'Cable TV', 'Essentials',...
# ...               ...                                                ...
# 5550              135  ['24-hour check-in', 'Air conditioning', 'Bath...
# 5551               87  ['24-hour check-in', 'Air conditioning', 'Buzz...
# 5552                0  ['Air conditioning', 'Buzzer/wireless intercom...
# 5553               89  ['24-hour check-in', 'Air conditioning', 'Cabl...
# 5554                0  ['Air conditioning', 'Elevator', 'Family/kid f...
#
# [5555 rows x 50 columns]

# %%
df.shape
# Out:
# (5555, 50)

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b666bf274d0a> in <cell line: 1>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined
